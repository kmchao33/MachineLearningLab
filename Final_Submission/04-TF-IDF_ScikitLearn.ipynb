# %% [markdown]
# ## Implement TF-IDF using Scikit-Learn Library
#
# Documentation: [TFidfVectorizer](http://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.TfidfVectorizer.html)
#
# Convert a collection of raw documents to a matrix of TF-IDF features.

# %%
import os
import json
from sklearn.feature_extraction.text import TfidfVectorizer
import pandas as pd
import pickle
import numpy as np

# %% [markdown]
# Before obtaining the TF-IDF matrix, make sure that text corpus is generate during preprocessing. If not, go back to [Corpus Generation](03-Corpus_Generation.ipynb).
#
# #### 1. Calculate TF-IDF on preprocessed documents
# - params:
#     - processed_doc_path: file that has been preprocessed
#     - document_limit: restrict the number to process with tf-idf
# - variables:
#     - dictionary: set, to save unique token
#     - documents_list: list, for each document, there is a documents_list to save all tokens that occured
#     - files_list: to save file name

# %%
def scikit_tf_idf_PrerocessedDoc(processed_doc_path, document_limit=200):
    
    dictionary = set()
    documents_list = []
    files_list = []
    
    for root, dirs, files in os.walk(processed_doc_path):
        for f in files:
            document_limit -= 1
            files_list.append(f)
            print('.', end='')
            words_list = ''
            with open(root+'/'+f, 'rb') as fr:
                try:
                    words = pickle.load(fr)
                    for word in words:
                        dictionary.add(word)
                        words_list += word + ' '
                except:
                    print ('Error while processing file: ', f)
            
            documents_list.append(words_list)
            
            if document_limit == 0:
                print('\n')
                break

    sklearn_vector = TfidfVectorizer(vocabulary=dictionary)
    sklearn_tf_idf = sklearn_vector.fit_transform(documents_list)
    return sklearn_vector, sklearn_tf_idf, files_list

# %% [markdown]
# <font color="blue"/>
#
# ### dsp:
#   * Your `sklearn_vector` is not a vector but an algorithm, namely a vectorizer.
#   * For me `documents`, `files` would be as good as `documents_list`, `files_list`.
#   * You can get rid of the for-loop over words: `dictionary.update(words)` plus `words_list = ' '.join(words)`.

# %%
# %%time
#please modify the relative path
# processed_doc_path = '/home/bit/ma0/LabShare/data/chui_ma/spacy_corpus/'
processed_doc_path = '../spacy_corpus/'
sklearn_vector, sklearn_tf_idf, files_list = scikit_tf_idf_PrerocessedDoc(processed_doc_path, 200)
# Out:
# ........................................................................................................................................................................................................
#
# CPU times: user 1.02 s, sys: 56 ms, total: 1.08 s
# Wall time: 957 ms

# %% [markdown]
# #### 2. Find most important words using tf-idf
# - how often does a word appear in a report => “term frequency tf ”
# - how rare is a word across all reports => “inverse document frequency idf”
# - => importance score = tf * idf
# - params:
#     - sklearn_vector: a vector generated by TfidfVectorizer
#     - tf_idf: matrix, obtain from function: scikit_tf_idf_PrerocessedDoc(processed_doc_path, document_limit=200)
#     - k: number of keywords to display
#     - filenames: list of file names
# - variables:
#     - document_important_words: dict, key: file name, value: important words after calculating tf-idf

# %%
def sklearn_find_top_k_words(sklearn_vector, tf_idf, k, filenames):
    
    document_important_words = {}
    corpus = sklearn_vector.get_feature_names()
    
    for i in range(tf_idf.shape[1]):
        important_words = []
        
        #get indices of k-maximum values in numpy column
        index = np.argpartition(tf_idf[:, i], -k)[-k:]
        index = index[::-1]
        
        for ind in index:
            important_words.append(corpus[ind])
        
        document_important_words[filenames[i]] = important_words
        
        df = pd.DataFrame(document_important_words)
    return df

# %% [markdown]
# Find the most important 10 keywords in each business report, according the the term weighting matrix obtained in tf_idf

# %%
#find most important 10 keywords
#return pandas DataFrame
sk_tf_idf = np.transpose(sklearn_tf_idf)
sklearn_find_top_k_words(sklearn_vector, sk_tf_idf.toarray(), 10, files_list)
# Out:
#   NORMA_Group-QuarterlyReport-2016-Q2 DIC-Asset-AnnualReport-2015  \
# 0                         vergleichen                   immobilie
# 1                              region                aufsichtsrat
# 2                                juni                       aktie
# 3                             quartal                   vorstehen
# 4                            halbjahr                 unternehmen
# 5                               monat                        fond
# 6                               ebita                     balance
# 7                                höhe                gesellschaft
# 8                            dezember                       grund
# 9                          aufwendung                        höhe
#
#   HeidelbergCement-QuarterlyReport-2011-Q3 WCM-QuarterlyReport-2011-Q3  \
# 0                                  anleihe                gesellschaft
# 1                                   zement             verlustvorträge
# 2                                september          insolvenzverfahren
# 3                           zuschlagstoffe  körperschaftsteuergesetzes
# 4                         heidelbergcement                    investor
# 5                                     höhe                     oktober
# 6                            konzerngebiet               gewerbesteuer
# 7                           bauaktivitäten                    gespräch
# 8                            klinkerabsatz            jahresabschlüsse
# 9                                 republik                     problem
#
#   Capital_Stage-QuarterlyReport-2012-Q1 Hugo_Boss-AnnualReport-2010  \
# 0                            solarstrom                   metzingen
# 1                                  park               einzelhandels
# 2                          solarthermie                aufsichtsrat
# 3                               prozent                     konzern
# 4                            solarparks               geschäftsjahr
# 5                               quartal                     permira
# 6                                 stage                 unternehmen
# 7                                ausbau                    dezember
# 8                                 solar                  kollektion
# 9                          erneuerbaren                     manager
#
#   Sartorius-QuarterlyReport-2012-Q3 Wirecard-AnnualReport-2016  \
# 0                           vorjahr                  acquiring
# 1                            sparte                    payment
# 2                         sartorius                       visa
# 3                            biohit                unternehmen
# 4                          handling                     risiko
# 5                            liquid         zahlungsabwicklung
# 6                        industrial                    prozent
# 7                          einbezug                    händler
# 8                     sondereffekte                   wirecard
# 9                          dezember                    bereich
#
#   KwsSaat-QuarterlyReport-2011-Q2 NORMA_Group-QuarterlyReport-2014-Q2  \
# 0                          gruppe                         vergleichen
# 1                        züchtung                                juni
# 2                 segmentergebnis                                five
# 3                         roundup                                höhe
# 4                         segment                             quartal
# 5                     maissaatgut                               monat
# 6                  strukturkosten                            halbjahr
# 7             halbjahresabschluss                               ebita
# 8                        halbjahr                               group
# 9                          kläger                             schulde
#
#                ...              NORMA_Group-QuarterlyReport-2011-Q2  \
# 0              ...                                         halbjahr
# 1              ...                                       börsengang
# 2              ...                                          quartal
# 3              ...                                         wachstum
# 4              ...                                             höhe
# 5              ...                                     börsenganges
# 6              ...                                           kosten
# 7              ...                                  kapitalerhöhung
# 8              ...                                            kunde
# 9              ...                                             juni
#
#   TlgImmobilien-QuarterlyReport-2016-Q1 Hornbach-QuarterlyReport-2014-Q3  \
# 0                               quartal                             like
# 1                             immobilie                   thanksaboveall
# 2                                  märz             thatdiydemandoutside
# 3                                 hotel                          the2013
# 4                           assetklasse                        terof2014
# 5                                ankauf                       itsoftware
# 6                           vergleichen  thegroupsignificantlyoffsethigh
# 7                                  büro                    sseverewinter
# 8                           verpachtung    thediystoreswithgardencenters
# 9                              ergebnis                      itssalesby1
#
#   WackerChemie-QuarterlyReport-2013-Q2 Gerry_Weber-AnnualReport-2013  \
# 0                               wacker                     hallhuber
# 1                                 juni                    kollektion
# 2                              quartal               verkaufsflächen
# 3                         polysilicium                        retail
# 4                              vorjahr                       vorjahr
# 5                              betonen                        gruppe
# 6                              prozent                 geschäftsjahr
# 7                           vorquartal                        houses
# 8                      berichtsquartal                        risiko
# 9                               chemie                     wholesale
#
#   TAKKT-QuarterlyReport-2014-Q3 Wacker_Neuson-QuarterlyReport-2015-Q3  \
# 0                        topdeq                            baugeräten
# 1             geschäftsbereichs                               prozent
# 2                         takkt                                 m2014
# 3                       prozent                               konzern
# 4                gesellschaften                      kompaktmaschinen
# 5                     september                               vorjahr
# 6                      sonstige                               quartal
# 7                        ebitda                                umsatz
# 8                        stufen                                 monat
# 9                         monat                             september
#
#     MLP-AnnualReport-2014 EvonikIndustries-QuarterlyReport-2012-Q3  \
# 0  finanzdienstleistungen                                  prozent
# 1            aufsichtsrat                                   evonik
# 2                 vorjahr                                   wohnen
# 3                 berater                              fotovoltaik
# 4           finanzholding                        produktionsanlage
# 5     vermögensmanagement                                 vivawest
# 6           geschäftsjahr                                geschäfts
# 7          altersvorsorge                                    steag
# 8                  risiko                                  segment
# 9             unternehmen                            bereinigungen
#
#   Hella-QuarterlyReport-2014-Q3
# 0                         hella
# 1                       vorjahr
# 2        altersteilzeitprogramm
# 3                      wachstum
# 4                      fahrzeug
# 5                neuzulassungen
# 6                          kgaa
# 7                     lippstadt
# 8                          behr
# 9              geschäftsquartal
#
# [10 rows x 200 columns]
